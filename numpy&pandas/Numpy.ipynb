# %%
import numpy as np

# %% [markdown]
# ### 1.3. Creating numpy arrays
# The key feature of numpy is its __N-dimensional array__ or __ndarray__, having the below specialities:<br/>
# - It is fast and flexible container for large datasets in Python.
# - These arrays enable you to carry mathematical operations on __whole block of data__.
# - It is a generic multi-dimensional container for data, where each element is of the __same type__. Below we will see some         examples of ndarray.
# - Below is an  image showing 1D, 2D and 3D arrays.<br/>

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
a = np.array([1,2,3,]) # one dimensional array
b = np.array([(1.5,2,3),(4,5,6)], dtype=float) #two dimensional array
c = np.array([[(1.5,2,3),(4,5,6)],[(3,2,1),(4,5,6)]], dtype=float) # three dimensional array
print(a)
print('************')
print(b)
print('************')
print(c)
# Out:
# [1 2 3]
# ************
# [[1.5 2.  3. ]
#  [4.  5.  6. ]]
# ************
# [[[1.5 2.  3. ]
#   [4.  5.  6. ]]
#
#  [[3.  2.  1. ]
#   [4.  5.  6. ]]]

# %%
b.shape # shape of the array
len(a)  # length of the array
b.ndim # dimensions of the array
a.size # number of the array elements
b.dtype.name # name of the data type
d.astype(int) # convert an array into different type
# Out:
# 2

# %%
np.info(np.ndarray.dtype) # for help
# Out:
# Data-type of the array's elements.
#
# Parameters
# ----------
# None
#
# Returns
# -------
# d : numpy dtype object
#
# See Also
# --------
# numpy.dtype
#
# Examples
# --------
# >>> x
# array([[0, 1],
#        [2, 3]])
# >>> x.dtype
# dtype('int32')
# >>> type(x.dtype)
# <type 'numpy.dtype'>

# %%
g = a-b   # substraction
print(g)
print('------')
np.subtract(a,b)
# Out:
# [[-0.5  0.   0. ]
#  [-3.  -3.  -3. ]]
# ------
# array([[-0.5,  0. ,  0. ],
#        [-3. , -3. , -3. ]])

# %%
g = a+b #addition
print(g)

print('------------')

np.add(b,a)
# Out:
# [[2.5 4.  6. ]
#  [5.  7.  9. ]]
# ------------
# array([[2.5, 4. , 6. ],
#        [5. , 7. , 9. ]])

# %%
g =  a/b #division
print(g)
print('-------------------')

np.divide(a,b)
# Out:
# [[0.66666667 1.         1.        ]
#  [0.25       0.4        0.5       ]]
# -------------------
# array([[0.66666667, 1.        , 1.        ],
#        [0.25      , 0.4       , 0.5       ]])

# %%
g = a*b              #multiplication
print(g)
print('------------')
np.multiply(a,b)
# Out:
# [[ 1.5  4.   9. ]
#  [ 4.  10.  18. ]]
# ------------
# array([[ 1.5,  4. ,  9. ],
#        [ 4. , 10. , 18. ]])

# %%
np.exp(a)  # Exponentiation
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
np.sqrt(a)   # square root
# Out:
# array([1.        , 1.41421356, 1.73205081])

# %%
np.sin(a)  # print sines of an array
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
np.cos(c)  # print elementwise cosine
# Out:
# array([[[ 0.0707372 , -0.41614684, -0.9899925 ],
#         [-0.65364362,  0.28366219,  0.96017029]],
#
#        [[-0.9899925 , -0.41614684,  0.54030231],
#         [-0.65364362,  0.28366219,  0.96017029]]])

# %%
np.log(a)   # print natural logarithm
# Out:
# array([0.        , 0.69314718, 1.09861229])

# %%
a.dot(a)    # Dot product
# Out:
# 14

# %%
a == b     # element wise comparision
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True]])

# %%
a < 2   # element wise comparision
# Out:
# array([[ True, False, False],
#        [False, False, False]])

# %%
k = np.array_equal(a,b)     # array wise comparision
print(k)
print(a)
print(b)
# Out:
# True
# [[1.5 2.  3. ]
#  [4.  5.  6. ]]
# [[1.5 2.  3. ]
#  [4.  5.  6. ]]

# %%
a.sum()   # sum of all the elements in the array
# Out:
# 21.5

# %%
a.min()   # minimum value from the element
# Out:
# 1.5

# %%
b.max(axis=0)   # maximum values of the an array row
# Out:
# array([4., 5., 6.])

# %%
b.cumsum(axis=1)   #cumulative sum of the elements in a row
# Out:
# array([[ 1.5,  3.5,  6.5],
#        [ 4. ,  9. , 15. ]])

# %%
a.mean()   # mean value of all elements
# Out:
# 3.5833333333333335

# %%
b.mean(axis=0)   # mean values of the each column
# Out:
# array([2.75, 3.5 , 4.5 ])

# %%
np.corrcoef(a)    # correlation coefficient
# Out:
# array([[1.        , 0.98198051],
#        [0.98198051, 1.        ]])

# %%
np.std(b)  # standard deviation
# Out:
# 1.5920810978785667

# %%
h = a.view()   # creating a view of the array with the same data
h
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
np.copy(a)  # createa copy of the array
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
h = a.copy()   # create deep copy of the array
h
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
a.sort()   # sort an array
c.sort(axis=0) # sort the elements of an arra's axis
